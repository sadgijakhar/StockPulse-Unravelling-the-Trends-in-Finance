# %% [markdown]
# # ***************************** Analysis Of Stock [A] *******************************

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading DataSet

# %%
df = pd.read_csv('/Users/sadgijakhar/Downloads/individual_stocks_5yr/A_data.csv')

# %%
df
# Out:
#             date   open    high     low  close   volume Name
# 0     2013-02-08  45.07  45.350  45.000  45.08  1824755    A
# 1     2013-02-11  45.17  45.180  44.450  44.60  2915405    A
# 2     2013-02-12  44.81  44.950  44.500  44.62  2373731    A
# 3     2013-02-13  44.81  45.240  44.680  44.75  2052338    A
# 4     2013-02-14  44.72  44.780  44.360  44.58  3826245    A
# ...          ...    ...     ...     ...    ...      ...  ...
# 1254  2018-02-01  73.18  73.780  72.510  72.83  2008177    A
# 1255  2018-02-02  72.32  72.760  71.220  71.25  1955697    A
# 1256  2018-02-05  70.86  71.480  68.180  68.22  2860726    A
# 1257  2018-02-06  66.96  68.830  66.130  68.45  4121239    A
# 1258  2018-02-07  68.19  69.085  67.905  68.06  1988391    A
#
# [1259 rows x 7 columns]

# %% [markdown]
# ## 1) Data Exploration:
# Take a look at the data to understand its structure and what information it contains. Identify the columns/features available such as Open, Close, High, Low, Volume, Date, and Name for each stock.

# %%
df.head()
# Out:
#         date   open   high    low  close   volume Name
# 0 2013-02-08  45.07  45.35  45.00  45.08  1824755    A
# 1 2013-02-11  45.17  45.18  44.45  44.60  2915405    A
# 2 2013-02-12  44.81  44.95  44.50  44.62  2373731    A
# 3 2013-02-13  44.81  45.24  44.68  44.75  2052338    A
# 4 2013-02-14  44.72  44.78  44.36  44.58  3826245    A

# %%
df.shape
# Out:
# (1259, 7)

# %%
df.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   object
#  1   open    1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   close   1259 non-null   float64
#  5   volume  1259 non-null   int64
#  6   Name    1259 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 69.0+ KB

# %%
print(df['Name'].unique())
# Out:
# ['A']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   datetime64[ns]
#  1   open    1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   close   1259 non-null   float64
#  5   volume  1259 non-null   int64
#  6   Name    1259 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 69.0+ KB

# %%
df.describe()
# Out:
#                                 date         open         high          low  \
# count                           1259  1259.000000  1259.000000  1259.000000
# mean   2015-08-09 05:44:16.393963264    49.187863    49.600059    48.782026
# min              2013-02-08 00:00:00    33.180000    34.060000    33.115000
# 25%              2014-05-10 12:00:00    41.515000    41.870000    41.260000
# 50%              2015-08-10 00:00:00    46.640000    47.000000    46.341000
# 75%              2016-11-05 12:00:00    56.435000    56.935000    56.025000
# max              2018-02-07 00:00:00    74.480000    75.000000    74.300000
# std                              NaN     9.244798     9.264168     9.197698
#
#              close        volume
# count  1259.000000  1.259000e+03
# mean     49.202025  2.338039e+06
# min      33.370000  5.328630e+05
# 25%      41.560000  1.533018e+06
# 50%      46.700000  2.003109e+06
# 75%      56.495000  2.718401e+06
# max      74.820000  1.814641e+07
# std       9.229804  1.400161e+06

# %% [markdown]
# ## 2) Data Preprocessing:

# %% [markdown]
# ###### Converting Date column Object to DateAndTime

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
print(df['date'].dtypes)
# Out:
# datetime64[ns]

# %% [markdown]
# ## 3) Initial Analysis:

# %% [markdown]
# #### Stock Price Trend Over Time:
# Trying understand the trends and patterns of stock throghtout the 5 years

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['close'], label='Closing Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Price Trend Over Time')
plt.legend()
plt.show()

# %%
# Plotting volume trends over time
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['volume'], color='green', label='Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Volume Trend Over Time')
plt.legend()
plt.show()

# %% [markdown]
# #### Volume Trend Over Time:
# This plot displays the trading volume of the stock over time. It provides insights into the level of market activity and can help identify periods of high or low trading activity.
